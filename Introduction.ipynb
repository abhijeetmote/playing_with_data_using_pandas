# %% [markdown]
# # PyCon Italy 2019 : Playing with data using Python and Pandas
#
# ## Github repository
#
# - Download the data from GitHub
# - Open your Python environment ()
#
# ## Instructor : Abhijeet Mote
#
# ***

# %% [markdown]
# ## Basic Concepts
#
# The following line imports the *sys* module and prints the *Python* version:

# %%
import sys
print(sys.version)
# Out:
# 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]

# %% [markdown]
# The following line imports the *pandas* module and prints the *Python* version:

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 0.23.4

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.16.2

# %%
import matplotlib as mpl
print(mpl.__version__)
# Out:
# 3.0.2

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Note:</b>It’s conventional to refer to ‘pandas’ as ‘pd’. When you add the as pd at the end of your import statement, your Jupyter Notebook understands that from this point on every time you type pd, you are actually referring to the pandas library
# </div>

# %% [markdown]
# # Reading the data using python

# %%
import os
print("\n Before:", os.getcwd())
os.chdir(r"C:\Users\IOT-A218LPEN\Downloads\data")
print("\n After:", os.getcwd())

print("\n listing of files \n\n", os.listdir())
# Out:
#  Before: C:\Users\IOT-A218LPEN\Desktop\backup
#
#  After: C:\Users\IOT-A218LPEN\Downloads\data
#
#  listing of files
#
#  ['blooth_sales_data.csv', 'blooth_sales_data.html', 'blooth_sales_data.json', 'blooth_sales_data.xlsx', 'blooth_sales_data_2.csv', 'blooth_sales_data_clean.csv', 'blooth_sales_data_clean.xlsx', 'blooth_sales_data_clean_1.csv', 'blooth_sales_data_clean_2.csv', 'blooth_sales_data_clean_3.csv', 'pandas_tutorial_read.csv', 'Salaries.csv', 'sales_data_json_exported.xlsx', 'sampledf.json', 'temp.csv', 'temp_txt_data.txt']

# %% [markdown]
# # How to read the data from any file?

# %%
with open("blooth_sales_data.csv") as obj:
    print(obj.readlines())
# Out:
# ['name,birthday,customer,orderdate,product,units,unitprice\n', 'Pasquale,1967-09-02,Electronics Inc,2016-07-17 13:48:03.156566,Thriller record,2,13.27\n', 'India,1968-12-13,Electronics Resource Group,2016-07-06 13:48:03.156596,Corolla,26,24458.69\n', 'Wayne,1992-09-10,East Application Contract Inc,2016-07-22 13:48:03.156618,Rubikâ€™s Cube,41,15.79\n', 'Cori,1986-11-05,Signal Industries,2016-07-23 13:48:03.156638,iPhone,16,584.01\n', 'Chang,1972-04-23,Star Alpha Industries,2016-07-16 13:48:03.156657,Harry Potter book,4,25.69\n', 'Weldon,1953-03-17,Network Application Co,2016-07-22 13:48:03.156678,Lipitor,1,11.22\n', 'Sung,1977-10-23,Omega Pacific Future Incorporated,2016-07-09 13:48:03.156698,PlayStation,25,294.9\n', 'Emily,1982-07-02,Medicine Incorporated,2016-07-16 13:48:03.156717,Thriller record,5,18.27\n', 'Cornell,1963-07-02,Technology Direct Star Limited,2016-07-08 13:48:03.156735,Rubikâ€™s Cube,35,15.98\n', 'Ervin,1977-10-14,Provider Agency,2016-07-19 13:48:03.156754,Star Wars,
# ...

# %% [markdown]
# # Reading Data Across Multiple Formats
# * CSV
# * text
# * Excel
# * JSON

# %%
import pandas as pd
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'Interval',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseSeries',
#  'Term',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt64Index',
#  'WidePanel',
#  '_DeprecatedModule',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p13',
#  '_np_version_under1p14',
#  '_np_version_under1p15',
#  '_tslib',
#  '_version',
#  'api',
# ...

# %%
### Read CSV file using Pandas

# %%
df1 = pd.read_csv("blooth_sales_data.csv")
# Out:
#            name    birthday                                 customer  \
# 0      Pasquale  1967-09-02                          Electronics Inc
# 1         India  1968-12-13               Electronics Resource Group
# 2         Wayne  1992-09-10            East Application Contract Inc
# 3          Cori  1986-11-05                        Signal Industries
# 4         Chang  1972-04-23                    Star Alpha Industries
# 5        Weldon  1953-03-17                   Network Application Co
# 6          Sung  1977-10-23        Omega Pacific Future Incorporated
# 7         Emily  1982-07-02                    Medicine Incorporated
# 8       Cornell  1963-07-02           Technology Direct Star Limited
# 9         Ervin  1977-10-14                          Provider Agency
# 10         Odis  1985-07-05                 Technology International
# 11      Cornell  1963-07-02           Technology Direct Star Limited
# 12        Kelli  1982-05-10              Building Construction Group
# ...

# %% [markdown]
# ### Read txt file using Pandas

# %%
df2 = pd.read_csv("temp_txt_data.txt")

# %%
pd.read_csv?

# %% [markdown]
# ### Read excel file using Pandas

# %%
df3 = pd.read_excel("sales_data_json_exported.xlsx")
print(df3)

# %% [markdown]
# ### Read json file using Pandas

# %%
df3 = pd.read_json("blooth_sales_data.json")
print(df3)

# %% [markdown]
# # Great you are able to import the data :)

# %% [markdown]
# # Lets see some theory of Series and DataFrames
